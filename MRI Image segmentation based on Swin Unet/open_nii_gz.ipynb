# %% [markdown]
# 19. this is vuslizing the results consisting visulizing the main MRI image, GT and prediction

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/MyDrive/Colab Notebooks/nn new/output/predictions
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/nn new/output/predictions

# %%
import nibabel as nib
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
import random
from  matplotlib import pyplot as plt

# %%
img = nib.load('case0022_img.nii.gz').get_fdata()
gt = nib.load('case0022_gt.nii.gz').get_fdata()
pred = nib.load('case0022_pred.nii.gz').get_fdata()
#cropped = img[start_row:end_row, start_col:end_col]
#print(img.shape[-1])

#Scalers are applied to 1D so let us reshape and then reshape back to original shape. 
#img=scaler.fit_transform(img.reshape(-1, img.shape[-1])).reshape(img.shape)

# %% [markdown]
# # ground truth and CT

# %%
n_slice=random.randint(0, img.shape[2])
print(n_slice)

plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.imshow(img[:,:,n_slice], cmap='gray')

plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.imshow(gt[:,:,n_slice], cmap='jet')
# Out:
# 56

# %% [markdown]
# # prediction

# %%
plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.imshow(pred[:,:,n_slice], cmap='jet')
